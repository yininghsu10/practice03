# %%
#Costco推薦排行榜專案最終版
from tkinter import *
import tkinter as tk
from tkinter.messagebox import *
from tkinter import messagebox
import webbrowser
import pandas as pd

#背景
window = Tk()
window.geometry("1447x728")
window.configure(bg = "#FFFFFF")
canvas = Canvas(
    window,
    bg = "#FFFFFF",
    height = 728,
    width = 1447,
    bd = 0,
    highlightthickness = 0,
    relief = "ridge")
canvas.place(x = 0, y = 0)

background_img = PhotoImage(file = f"background.png")
background = canvas.create_image(
    723.5, 364.0,
    image=background_img)

pd.set_option('display.unicode.ambiguous_as_wide', True)
pd.set_option('display.unicode.east_asian_width', True)

#點擊按鈕觸發FB爬蟲、Costco爬蟲
def btn_clicked():
    print("Button Clicked")
    
    #FB爬蟲匯入mongoDB
    import pandas as pd
    import os
    import time
    import requests
    from bs4 import BeautifulSoup
    from selenium import webdriver
    from chromedriver_py import binary_path
    from selenium import webdriver
    from selenium.webdriver.chrome.options import Options
    import random
    import pandas as pd
    import pymongo
    from pymongo import MongoClient
    import tkinter as tk
    from tkinter import messagebox
    
    global df_extract
    global df
    global df2
    
    client = pymongo.MongoClient("mongodb+srv://test:test@cluster0.j7nzi.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
    db = client.costco
    col = db.FB_pythons

    x = col.delete_many({})
    print(x.deleted_count, "個已删除")
    #wb=openpyxl.Workbook()
    #ws=wb.active

    # 你的資訊
    url = "https://www.facebook.com/"
    email = "linden710127@yahoo.com.tw"
    password = "61252483"
    
#-----------------------------------------------------------------------------
#     # 防止跳出通知
    chrome_options = webdriver.ChromeOptions()
    prefs = {
        "profile.default_content_setting_values":{"notifications": 2}
    }
    chrome_options.add_experimental_option("prefs", prefs)
 
    # 使用ChromeDriverManager自動下載chromedriver
    driver = webdriver.Chrome(executable_path = binary_path)


#-----------------------------------------------------------------------------
    # 最大化視窗
    driver.maximize_window()
    # 進入Facebook登入畫面
    driver.get(url)

    # 填入帳號密碼，並送出
    driver.find_element_by_id("email").send_keys(email)
    driver.find_element_by_id("pass").send_keys(password)
    driver.find_element_by_name("login").click()

    time.sleep(5)
    
    #-----------------------------------------------------------------------------
# #     # 防止跳出通知
#     chrome_options = webdriver.ChromeOptions()
#     prefs = {
#         "profile.default_content_setting_values":{"notifications": 2}
#     }
#     chrome_options.add_experimental_option("prefs", prefs)
 
#     # 使用ChromeDriverManager自動下載chromedriver
#     driver = webdriver.Chrome(executable_path = binary_path)
#     #    ChromeDriverManager().install(), chrome_options=chrome_options)
#     # 最大化視窗
#     driver.maximize_window()


#-----------------------------------------------------------------------------
    
    # 進入Costco好市多 商品經驗老實說
    driver.get("https://www.facebook.com/groups/1260448967306807?sorting_setting=CHRONOLOGICAL")   
    time.sleep(5)

    # 往下滑10次，讓Facebook載入文章內容
    for x in range(20):
        driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
        print("scroll",x)
        time.sleep(random.randint(3,5))

    root = BeautifulSoup(driver.page_source, "html.parser")

    # 定位文章標題
    titles = root.find_all(
        "div", class_="ecm0bbzt hv4rvrfc ihqw7lf3 dati1w0a")
    for title in titles:
        # 定位每一行標題
        posts = title.find_all("div", class_="kvgmc6g5 cxmmr5t8 oygrvhab hcukyx3x c1et5uql ii04i59q")
        # 如果有文章標題才印出
        if len(posts) != 0:
            for post in posts:
                #print(post.text)
                #ws.append([post.text])
                #新增單筆資料
                st={"FB內文":post.text
                   } 
            result=col.insert_one(st)
    os.system('taskkill /im chromedriver.exe /F')
    os.system('taskkill /im chrome.exe /F')

   

    #----------------------------------------

    #FB爬蟲做成文字雲Dataframe

    from pymongo import MongoClient
    import pandas as pd
    
    #連接MongoDB
    client = pymongo.MongoClient("mongodb+srv://test:test@cluster0.j7nzi.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
    #指定資料庫
    db = client.costco
    #指定資料表
    col=db.FB_pythons
    #直接從MongoDB查詢
    post=col.distinct("FB內文")
    print(post)

    #將FB內文進行斷詞
    import jieba
    word=[]
    for i in post:
        a=jieba.cut(i)    
        word+=a
    print(word)   

    #統計每個字串出現次數 #把每個字串當成key去計算出現的次數(當成值)
    dic_w={}
    #判斷KEY(ele)是否在dic_w{}裡面
    for ele in word:
        #如果KEY(ele)不在dic_w{}裡面,如果KEY沒出現過，就新增一筆KEY並讓值從1開始
        if ele not in dic_w:
            dic_w[ele]=1
        #如果KEY重複出現，值(AKA次數)就+1
        else:
            dic_w[ele]+=1
    print(dic_w)

    #調整顯示方式 #因為dic是無序的，所以要用.items來排序呼叫
    for ele in dic_w.items():
        #兩個字以上的，才會出現
        if len(ele[0])>=2: 
            num=list()
            word=list()
            #因為經過.items的關係，變成(0,1)=(前面,後面)

    #要排序次數
    import operator
    #itemgetter是指出現該函數內第幾個的意思(從0開始數)
    #.itemgetter()從0開始會變成依筆畫排列
    sort_w=sorted(dic_w.items(),key=operator.itemgetter(1),reverse=True)
    num=[]
    word=[]
    for ele in sort_w:
        if len(ele[0])>=2 and ele[1]>=2:
            word.append(ele[0])
            num.append(ele[1])   
    df_extract=pd.DataFrame({'num':num,'word':word})
    print(df_extract)

    #----------------------------------------

    #Costco爬蟲食品清單1

#     import requests #請求
#     from bs4 import BeautifulSoup #BS要大寫
#     import time
#     import random
#     import pymongo
#     import openpyxl #匯入EXCEL格式

    #至少要有一筆資料，資料庫才能存在(沒辦法建立空資料庫)
    #建立資料庫
    client = pymongo.MongoClient("mongodb+srv://test:test@cluster0.j7nzi.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
    db = client.costco
    #建立collection
    col=db.commodity
    x = col.delete_many({})

    print(x.deleted_count, "筆舊資料已删除")

    res=requests.get('https://www.costco.com.tw/c/CL8?') #網址是字串
    soup=BeautifulSoup(res.text)
    # print(soup.html.body.h1.string)
    # print(soup.prettify()) #輸出排版後的HTML內容

    #開啟一個工作簿
    # wb=openpyxl.Workbook() #只有W要大寫
    # ws=wb.active #在工作簿底下開一張新的工作表

    # ws["A1"]="商品名稱"
    # ws["B1"]="商品價格"
    # ws["C1"]="網址"

    # print(soup.find_all("ul",class_="product-listing product-grid")[0].find_all("li",class_="product-list-item product-list-item--grid vline ng-star-inserted")[0].prettify())

    for commodity in soup.find_all("ul",class_="product-listing product-grid")[0].find_all("li",class_="product-list-item product-list-item--grid vline ng-star-inserted"):
        #商品名稱
        a=commodity.find_all("a",class_="lister-name js-lister-name")[0].text
        #商品價格
        b=commodity.span.text
        #網址
        c=commodity.a["href"]

        #新增單筆資料   
        st={"商品名稱":a,
            "商品價格":b,
            "網址":c
            } 
        result=col.insert_one(st)
    #     print(a)
    #     print(b)
    #     print(c)
    #     ws.append([a,b,c]) #()內要放list
    #     wb.save("20220425_COSTCO商品清單.xlsx") #放在哪個位置決定多久存檔一次

    time.sleep(random.randint(1,3))

    #連接MongoDB
    client = MongoClient("mongodb+srv://test:test@cluster0.j7nzi.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
    #指定資料庫
    db = client.costco
    #指定資料表
    col=db.commodity
    #直接從MongoDB查詢
    name=col.distinct("商品名稱")
    price=col.distinct("商品價格")
    web=col.distinct("網址")

    df = pd.DataFrame(list(db.commodity.find({},{ "_id": 0, "商品名稱": 1, "商品價格": 1, "網址": 1 })))
    print(df)

    #----------------------------------------

     #Costco爬蟲賣場限定清單2

    #至少要有一筆資料，資料庫才能存在(沒辦法建立空資料庫)
    #建立資料庫

    client = pymongo.MongoClient("mongodb+srv://test:test@cluster0.j7nzi.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
    db = client.costco
    #建立collection
    col=db.commodity2
    x = col.delete_many({})

    print(x.deleted_count, "筆舊資料已删除")
    
    #隱藏瀏覽視窗不跳出
    chrome_options = Options()
    chrome_options.add_argument("--headless")
    driver = webdriver.Chrome(executable_path = 'C:\\Users\\user\\chromedriver.exe',options=chrome_options)

    driver.get("https://www.costco.com.tw/c/CLWH?q=:relevance:category:WH1205:category:WH1201:category:WH0806:category:WH1202:category:WH0811:category:WH1203:category:WH0808:category:WH1204:category:WH0810:category:WH0809:category:WH0807")
    #讓頁面自動往下滑
    driver.execute_script("window,scrollTo(0,document.body.scrollHeight)")
    time.sleep(5)
    soup = BeautifulSoup(driver.page_source,"html.parser")

    for commodity2 in soup.find_all("ul",class_="product-listing product-grid")[0].find_all("li",class_="product-list-item product-list-item--grid vline ng-star-inserted"):
        #商品名稱
        a=commodity2.find_all("a",class_="lister-name js-lister-name")[0].text
        #網址
        c="https://www.costco.com.tw/"+commodity2.a["href"]
#         print(a)
#         print(c)
#         print('-------------------')

        #新增單筆資料   
        st={"商品名稱":a,
            "網址":c
            } 
        result=col.insert_one(st)

    time.sleep(random.randint(1,3))

    #連接MongoDB
    client = MongoClient("mongodb+srv://test:test@cluster0.j7nzi.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
    #指定資料庫
    db = client.costco
    #指定資料表
    col=db.commodity2
    #直接從MongoDB查詢
    name=col.distinct("商品名稱")
    price=col.distinct("商品價格")
    web=col.distinct("網址")

    df2 = pd.DataFrame(list(db.commodity2.find({},{ "_id": 0, "商品名稱": 1, "商品價格": 1, "網址": 1 })))
    print(df2)


    root = tk.Tk()
    root.withdraw()
    messagebox.showinfo('系統提示', '資料已蒐集完畢，點擊「買什麼好呢」獲取推薦清單')
    
    return df_extract,df,df2
   
#背景爬蟲按鈕
img0 = PhotoImage(file = f"img0.png")
b0 = Button(
    image = img0,
    borderwidth = 0,
    highlightthickness = 0,
    command = btn_clicked,
    relief = "flat")

b0.place(
    x = 80, y = 193,
    width = 304,
    height = 133)


#介面def*2
    
#Costco清單1模糊比對結果
def shoplist1(): #定義按鈕使用功能
    import pandas as pd
    from fuzzywuzzy import fuzz
    from fuzzywuzzy import process
    
    global dfx
    global final
    global complete
    
    #FB貼文的斷詞
    chart=df_extract
    #Costco商品列表
    chart2=df

    def fuzzy_merge(chart, chart2, key1, key2, threshold=40, limit=1):
        """
        :param df_1: the left table to join
        :param df_2: the right table to join
        :param key1: key column of the left table
        :param key2: key column of the right table
        :param threshold: how close the matches should be to return a match, based on Levenshtein distance
        :param limit: the amount of matches that will get returned, these are sorted high to low
        :return: dataframe with boths keys and matches
        """
        s = chart2[key2].tolist()
        m = chart[key1].apply(lambda x: process.extract(x, s, limit=limit))
        chart['matches'] = m
        m2 = chart['matches'].apply(lambda x: ', '.join([i[0] for i in x if i[1] >= threshold]))
        chart['matches'] = m2
        chart['merge_key'] = chart['matches']
        chart2['merge_key'] = chart2[key2]
        dfx = pd.merge(chart, chart2, how='left',on='merge_key')
        return dfx

    dfx = fuzzy_merge(chart,chart2,'word','商品名稱',40)
    final=dfx.drop(['matches','merge_key'],axis=1,inplace=True)
    print(final)

    #資料清洗
#     complete=dfx.dropna().sort_values(["num"],ascending=0,ignore_index=True).drop(["num","word"],axis=1).drop_duplicates()[0:10]
    final=dfx.dropna().sort_values(["num"],ascending=0,ignore_index=True).drop(["num","word"],axis=1).drop_duplicates()[0:3]
    final.index=[1,2,3]
    print(dfx)
#     l1.config(text=final,justify="left",font=("微軟正黑體"))
#     return complete
    
    # 插入資料
    global ans
    final_dict=final.to_dict('list')
    for num in range(0,10):
        ans=[]
        a=final_dict["商品名稱"][num],final_dict["商品價格"][num],final_dict["網址"][num]
        ans.append(a)
        for index, data in enumerate(ans):
            table.insert('', END, values=data)  # 新增資料到末尾

#網址連結
def click_link(event):
    select = table.selection()
    values = table.item(select, 'values')
    link = values[2]
    print('link:', link)
    webbrowser.open(link)
        
#Costco清單2模糊比對結果
def shoplist2(): 
    #資料模糊比對流程整合
    import pandas as pd
    from fuzzywuzzy import fuzz
    from fuzzywuzzy import process
    
    global dfy
    global final2
    global complete2
    
    #FB貼文的斷詞
    chart=df_extract
    #Costco商品列表
    chart2=df2

    def fuzzy_merge(chart, chart2, key1, key2, threshold=40, limit=1):
        """
        :param df_1: the left table to join
        :param df_2: the right table to join
        :param key1: key column of the left table
        :param key2: key column of the right table
        :param threshold: how close the matches should be to return a match, based on Levenshtein distance
        :param limit: the amount of matches that will get returned, these are sorted high to low
        :return: dataframe with boths keys and matches
        """
        s = chart2[key2].tolist()
        m = chart[key1].apply(lambda x: process.extract(x, s, limit=limit))
        chart['matches'] = m
        m2 = chart['matches'].apply(lambda x: ', '.join([i[0] for i in x if i[1] >= threshold]))
        chart['matches'] = m2
        chart['merge_key'] = chart['matches']
        chart2['merge_key'] = chart2[key2]
        dfy = pd.merge(chart, chart2, how='left',on='merge_key')
        return dfy

    dfy = fuzzy_merge(chart,chart2,'word','商品名稱',40)
    final2=dfy.drop(['matches','merge_key'],axis=1,inplace=True)
    print(dfy)

    #資料清洗
#     complete2=dfy.dropna().sort_values(["num"],ascending=0,ignore_index=True).drop(["num","word"],axis=1).drop_duplicates()[0:10]
    final2=dfy.dropna().sort_values(["num"],ascending=0,ignore_index=True).drop(["num","word"],axis=1).drop_duplicates()[0:3]
    final2.index=[1,2,3]
    print(final2)
#     l2.config(text=final2,justify="left",font=("微軟正黑體"))
#     return complete2

# 插入資料
    global ans2
    final_dict2=final2.to_dict('list')
    for num in range(0,10):
        ans2=[]
        b=final_dict2["商品名稱"][num],final_dict2["網址"][num]
        ans2.append(b)
        for index, data in enumerate(ans2):
            table2.insert('', END, values=data)  # 新增資料到末尾

#網址連結2
def click_link2(event):
    select = table2.selection()
    values = table2.item(select, 'values')
    link = values[1]
    print('link:', link)
    webbrowser.open(link)
    
#背景清單1按鈕
img1 = PhotoImage(file = f"img1.png")
b1 = Button(
    image = img1,
    borderwidth = 0,
    highlightthickness = 0,
    command = shoplist1,
    relief = "flat")

b1.place(
    x = 1131, y = 13,
    width = 295,
    height = 63)

#背景清單2按鈕
img2 = PhotoImage(file = f"img2.png")
b2 = Button(
    image = img2,
    borderwidth = 0,
    highlightthickness = 0,
    command = shoplist2,
    relief = "flat")

b2.place(
    x = 1123, y = 364,
    width = 276,
    height = 53)

#treeview插入資料1
import tkinter
from tkinter import *
from tkinter import ttk

columns = ['商品名稱', '商品價格', '商品連結']
table = ttk.Treeview(
        master=window,  # 父容器
        height=10,  # 表格显示的行数,height行
        columns=columns,  # 显示的列
        show='headings',  # 隐藏首列
        )
table.bind("<Double-Button-1>", click_link)
table.heading(column='商品名稱', text='商品名稱')  # 定义表头
# table.heading(column='商品名稱', text='商品名稱', anchor='w',
#               command=lambda: print('商品名稱'))  # 定义表头
table.heading('商品價格', text='商品價格', )  # 定义表头
table.heading('商品連結', text='商品連結', )  # 定义表头

table.column('商品名稱', width=100, minwidth=100, anchor=S, )  # 定义列
table.column('商品價格', width=50, minwidth=50, anchor=S)  # 定义列
table.column('商品連結', width=150, minwidth=150, anchor=S)  # 定义列
table.place(
    x = 471, y = 77,
    width = 961,
    height = 272)

#treeview插入資料2
columns2 = ['商品名稱','商品連結']
table2 = ttk.Treeview(
        master=window,  # 父容器
        height=10,  # 表格显示的行数,height行
        columns=columns2,  # 显示的列
        show='headings',  # 隐藏首列
        )
table2.bind("<Double-Button-1>", click_link2)
table2.heading(column='商品名稱', text='商品名稱')  # 定义表头
# table.heading(column='商品名稱', text='商品名稱', anchor='w',
#               command=lambda: print('商品名稱'))  # 定义表头
table2.heading('商品連結', text='商品連結', )  # 定义表头

table2.column('商品名稱', width=100, minwidth=100, anchor=S, )  # 定义列
table2.column('商品連結', width=200, minwidth=200, anchor=S)  # 定义列
table2.place(
    x = 471, y = 425,
    width = 961,
    height = 272)

window.resizable(False, False)
window.mainloop()
# Out:
# Button Clicked
# 0 個已删除
# C:\Users\user\AppData\Local\Temp/ipykernel_11876/89996482.py:82: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path = binary_path)
# C:\Users\user\AppData\Local\Temp/ipykernel_11876/89996482.py:92: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id("email").send_keys(email)
# C:\Users\user\AppData\Local\Temp/ipykernel_11876/89996482.py:93: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id("pass").send_keys(password)
# C:\Users\user\AppData\Local\Temp/ipykernel_11876/89996482.py:94: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   driver.find_element_by_name("login").click()
# scroll 0
# scroll 1
# scroll 2
# scroll 3
# scroll 4
# scroll 5
# scroll 6
# scroll 7
# scroll 8
# scroll 9
# scroll 10
# scroll 11
# scroll 12
# scroll 13
# scroll 14
# scroll 15
# scroll 16
# scroll 17
# scroll 18
# scroll 19
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\user\AppData\Local\Temp\jieba.cache
# ['#歐美風起司拼盤#芝司樂起司球#高鈣起司#Hoodys精緻果乾#富統切片火腿…… 顯示更多', '2022/05/29蜂膠潤喉糖這個好ㄔ', '20220528 18:00野馬樂高在台中店(南屯) 還有20多盒直接搬了一盒', '5/28 剛剛11:50在台中好市多B1停車場推車上發現四瓶牛奶沒有拿，趕時間但有幫這位遺失者通知賣場人員取走放至櫃檯。（照片非推車上）', 'IPad Air大缺貨 先來一台MacBook Air#遠距教學最後一台金色#中和店 #其它顏色還有蠻多台的喔', 'Lego樂高經典系列特價$999', '[地方奶爸日記]孩子繼續線上上課一週，就用豬肉漢堡排來當一週早餐，做好以後放冷凍早上在放氣炸鍋氣炸快速上桌，小孩早餐可以吃的美味又健康！#兼職攝影師#全職奶爸#豬肉漢堡排', '不會狠辣的丫舍客家麻辣板條全家都喜歡吃加上當季食材小黃瓜很爽口￼', '中午經過好市多 ，想說進去買個黃色萬用布巾，經過咖啡機展示位 因為沒喝很大 對咖啡機也外行，考慮了一下後還是買了人生第一台咖啡機..試玩了幾杯 設定高水溫覺得水溫及奶泡溫度還不夠高 感覺味道不夠衝腦..看來還得要多摸索玩玩看，最後有個疑問要等廠商來看看怎麼回事，（就是使用後廢豆渣盒內會積不少水，水盤也會積不少水  看起來設計上應該不會是這種現像才對...）後續...經過一天的試作咖啡，豆渣水噴濺狀況已明顯改善 比較沒有和稀泥了，水盤有水是製作咖啡過程必須有的清洗動作所留下來的 也是正常無異，目前為止算是滿意的，作出來的咖啡是我預想的口感。對咖啡外行 要求的不多 也不懂咖啡眉眉角角，…… 顯示更多', '今天天氣終於放晴了 炎炎夏日立馬把Costco Arla鮮奶油拿出來做芒果冰淇淋我的媽啊 太好吃了 ', '今天早上到台南好市多買了兩台惠爾浦的除濕機因為在社團看到它的評價很好但是缺點就是噪音大但是沒有要放臥室…… 顯示更多', '今天煮燉飯時，突發奇想地丟幾塊kiri增加奶香&濃稠度，沒想到效果驚為天人！！！感覺拿來當白醬使用超級方便呀~~~推薦給大家試試！', '今天的主角不是我～是它們', '個人覺得元進莊的蔥油雞比全聯美味堂的好吃耶，口味比較重也更下飯，但兩家裏面附的蔥油包是一樣的。', '前次西瓜爆炸退款後，再賭瓜一次，這次西瓜好像貴了一點，大了一點，仔細挑選後沒爆炸的問題', '前陣子好市多的 #雞肉凱撒沙拉 漲價了，#昨天看到特價145元，覺得可以買來回味一下，不然那價格真的是越來越讓人不想下手…… 顯示更多', '前陣子看社團被推坑買了英國潔，想要用來除黴，效果如照片所示，好不好用見仁見智（只能怪自己，後來才發現產品上說明鋁金屬面不適用）', '哇哇哇～～～太可愛了啦！超大 #萌兔/#恐龍部隊 出沒完全可以擄獲小女孩/小男孩的心啊～', '唉 原本以為超幸運的在大順店剛好看到冰櫃裡剩下最後一盒立馬上前拿想說帶回家孝敬爸媽隔天迫不及待拿出來準備享用一打開就看到黑黑的一點', '好市多 蘇菲衛生棉很多款在特價喔然後這盒拉麵也有特價 希望煮出來好吃（不過我不太知道怎麼煮耶 求線上有人能教教我嗎）', '好市多今日採買專屬陪伴⋯⋯', '好市多的哈密瓜超級無敵甜超級好吃大家走過路過千萬別錯過大推！！！！！那天試吃後立刻搬兩顆走真…… 顯示更多', '好市多買的番茄真的品質很好⋯煮番茄牛肉⋯番茄炒蛋⋯跟牛腱起司下去烤還可以做成鍋子又可以雕花', '好的我衝動了請問大家都把瓶子拿來裝啥呢？「除了骨灰之外」', '從好市多線上購物買了龍蝦尾，做了奶油蒜香焗烤龍蝦，口感Q彈不錯吃。因為疫情關係，招待朋友不想上餐館，只好自己料理，如果之後疫情趨緩，龍蝦還是去外面吃好了....處理起來好累', '想問一下這隻好用嗎，還有他之前有特價過嗎感謝各位', '想請問有用過這款的人的心得', '新品-蕃茄櫛瓜麵包有人說它是比較健康的麵包今天買來嚐鮮味道是不錯的～蠻香的只是用手撈起來時，滿手的油…… 顯示更多', '新品情報連結 https://www.daybuy.tw/costco-37875Costco新商品，SOFY 蘇菲導管式衛生棉條，此款為量多型，每盒32入，日本製，現在有特價06/05前折價70元。', '新品情報連結 https://www.daybuy.tw/costco-37877Costco新商品，金頂1500流明露營燈，可使用太陽能或USB充電或使用4顆一號電池，可輸出電力當作行動電源。', '最近家人都在家用網路上班上課，食物耗損太快了！只好到好市多補貨咦！發現一個驚喜（應該沒看錯吧？）紐西蘭純淨的沐浴乳現在一組3入400ml才$489這也太划算了吧！因為之前我在網路上買一瓶也要$399…… 顯示更多', '最近疫情關係都在家開伙，今到好市多新莊補肉跟蛋，剛好看到這台賽寧的桌上型洗碗機想到最近都在家吃，洗碗真的洗到很厭世，感覺這台大小家裡3個人蠻剛好的，兩萬有找的價錢含裝到好真的蠻可以的，回去來跟老婆商量商量裝個一台來用用', '有人知道為何線上購物的凱優黑標貓砂下架了嗎？', '有人遇到橘子工坊洗衣精裡面是白白的嗎？先前先買回來庫存，都放在陰暗處。今天才開，裡面變這樣耶⋯這看起來好像不太正常⋯', '每天確診數都比我的月薪高 今天去採買物資真的有明顯感受到人有比較少一點餘光看到好多人在搬衛生棉我們好奇湊過去看是有什麼優惠 …… 顯示更多', '每次看社團有人分享這組馬卡龍回收控的我就想跟他要盒子來備用畢竟這馬卡龍盒子市面要買還不好買終於有一次厚臉皮的跟某社友要來一個(感謝－－－－－－－－－－－－－－－－－－－－…… 顯示更多', '為什麼漲價後….1次還要2箱….傻眼', '看到版友們分享用Fairy拿來洗各種東西都覺得很神奇這幾天居隔在家都快長香菇的時候突然在廚房發現年前大掃除的漏網之魚-抽油煙機集油網睡前把集油網丟進盆子裡後倒入Fairy早上起床竟然隨意刷一下就乾淨了耶…… 顯示更多', '真的有夠雷，一打開19包，改天拿去退，煩捏。', '終於有給小朋友吃的漢堡排了，不知道吃起來如何？', '老公感冒流鼻涕，在房間被我們隔離起來，我跟女兒相依為命，沒想到昨晚女兒說：我想要泡今天那個好喝的ㄋㄟㄋㄟ給爸爸喝，爸爸沒有喝到！！！嘖嘖嘖，真不愧是老公的前世情人啊！！…… 顯示更多', '記得前幾天有人貼過~#北投店', '說來真是羞愧 每次去好市多之前都跟老公放話說只有要買衛生紙而已，殊不知每次去結帳都一定2-3000起跳，都是攤位惹的禍！！經過攤位都腦波特弱！！！', '請問各位前輩線上購物購買的會是這樣的裸包 包裝嗎跟賣場包裝不同…… 顯示更多', '請問各位大大這罐好用嗎便宜700大洋好心動啊', '請問各位最近有人買這個貓咪肉條嗎？今天拿一串3包要餵貓咪們第一包貓咪們不吃、摸起來比之前的還要軟拿起來聞覺得酸酸的、…… 顯示更多', '請問各位這款壁掛架推嗎？自行安裝會很困難嗎？感謝各位大大解惑了', '請問有用這款母乳墊的有遇到殘膠的問題嗎？以前用都不會有殘膠最近買的這一箱膠都黏在內衣上撕不下來…', '請問此款商品營養標示 ，該去哪裡查詢？', '請問這一批藍莓是甜的嗎？', '請問這個肉質好嗎？未買，考慮中，求解～感謝！', '請問這可以凍嗎，不然應該不能2-3天就馬上吃完，怎麼保存', '請問這台是否推薦？考慮這台或者迪卡儂', '請問這款「蔓越莓綜合果汁」，大家覺得喝起來形容口感如何？？', '請問這款好用嗎？效能如何？壽命會不會很短？？', '請問這款特價的冷凍炸蝦口感如何？好吃嗎？謝謝', '請問這罐推嗎？或是有推哪罐比較保濕的呢？先謝謝各位的回應', '請問，柳橙汁裡面有類似茶包的東西，正常嗎⋯⋯', '買不到芍藥洋桔梗也行1把179便宜#花', '這些都是回購超多次的零嘴大家快去買哈哈哈', '雖然在家防疫 還是要認真戒糖減脂拉~~~不然防疫完都不知道胖多少XDDDD除了喝水外 肉類大多用好市多清雞胸代替我還會喝一大杯冰萃泡整晚的黑咖啡喝起來順口重點又無糖 放上一顆大冰塊…… 顯示更多', '露營早餐的好選擇，媽媽好省事，我家小孩說脆脆好香好好吃，加入牛奶也不容易軟爛～大推', '（跟媽媽一起逛好市多的惡趣味）：欸兒子這個好便宜喔：阿他快到期了啊：難怪這麼便宜：好市多也要友善食光阿…… 顯示更多', '𝑊𝐸𝐿𝑇𝐴𝐶𝐻𝑆貴族甜酒（無氣泡喔）']
# Loading model cost 0.818 seconds.
# Prefix dict has been built successfully.
# ['#', '歐美風', '起司', '拼盤', '#', '芝司', '樂起', '司球', '#', '高鈣', '起司', '#', 'Hoodys', '精', '緻', '果', '乾', '#', '富統', '切片', '火腿', '…', '…', ' ', '顯示', '更', '多', '2022', '/', '05', '/', '29', '蜂膠潤', '喉糖', '這個', '好', 'ㄔ', '20220528', ' ', '18', ':', '00', '野馬樂', '高', '在', '台', '中店', '(', '南屯', ')', ' ', '還有', '20', '多盒', '直接', '搬', '了', '一盒', '5', '/', '28', ' ', '剛剛', '11', ':', '50', '在', '台', '中', '好市', '多', 'B1', '停車場', '推車', '上', '發現', '四瓶', '牛奶', '沒有', '拿', '，', '趕時間', '但', '有', '幫', '這位', '遺失者', '通知', '賣場', '人員取', '走', '放至櫃', '檯', '。', '（', '照片', '非', '推車', '上', '）', 'IPad', ' ', 'Air', '大', '缺貨', ' ', '先來', '一台', 'MacBook', ' ', 'Air', '#', '遠距', '教學', '最', '後', '一台', '金色', '#', '中和店', ' ', '#', '其它', '顏色', '還有', '蠻', '多台', '的', '喔', 'Lego', '樂高', '經典', '系列', '特價', '$', '999', '[', '地方', '奶爸', '日記', ']', '孩子', '繼續線', '上', '上', '課', '一週', '，', '就', '用', '豬肉漢堡', '排來', '當一週', '早餐', '，', '做好', '以後放', '冷凍', '早上', '在', '放氣', '炸鍋', '氣炸', '快速', '上桌', '，', '小孩', '早餐', '可以', '吃', '的', '美味', '又', '健康', '！', '#', '兼職', '攝影師', '#', '全職', '奶爸', '#', '豬肉漢堡', '排', '不會', '狠辣', '的', '丫舍', '客家', '麻辣', '板條', '全家', '都', '喜歡', '吃', '加上', '當季', '食材', '小黃瓜', '很', '爽口', '￼', '中午', '經過', '好市', '多', ' ', '，', '想', '說', '進去', '買個', '黃', '色', '萬', '用布', '巾', '，', '經過', '咖啡', '機', '展示', '位', ' ', '因為', '沒', '喝', '很大', ' ', '對', '咖啡', '機', '也', '外行', '，', '考慮', '了', '一下', '後', '還是', '買', '了', '人生', '第一台', '咖啡', '機', '..', '試玩', '了', '幾杯', ' ', '設定', '高水', '溫覺', '得', '水溫', '及', '奶泡', '溫度', '還不夠', '高', ' ', '感覺', '味道', '不夠', '衝腦', '..', '看來', '還得', '要', '多', '摸索', '玩玩', '看', '，', '最後有', '個疑', '問要', '等', '廠', '商來', '看看', '怎麼', '回事', '，', '（', '就是', '使用', '後', '廢', '豆渣', '盒', '內會積', '不少', '水', '，', '水盤', '也', '會積', '不少', '水', ' ', ' ', '看起', '來', '設計', '上', '應該', '不會', '是', '這種', '現像', '才', '對', '...', '）', '後', '續', '...', '經過', '一天', '的', '試作', '咖啡', '，', '豆渣', '水噴濺', '狀況', '已', '明顯', '改善', ' ', '比較', '沒有', '和稀泥', '了', '，', '水盤', '有', '水', '是', '製', '作', '咖啡', '過程', '必須', '有', '的', '清洗', '動作', '所', '留下', '來', '的', ' ', '也', '是', '正常', '無異', '，', '目前', '為止', '算是', '滿意', '的', '，', '作出', '來', '的', '咖啡', '是', '我', '預想', '的', '口感', '。', '對', '咖啡', '外行', ' ', '要求', '的', '不', '多', ' ', '也', '不', '懂', '咖啡', '眉眉角角', '，', '…', '…', ' ', '顯示', '更', '多', '今天', '天氣終', '於', '放晴', '了', ' ', '炎炎夏日', '立馬', '把', 'Costco', ' ', 'Arla', '鮮', '奶油', '拿出', '來', '做', '芒果', '冰淇淋', '我的媽', '啊', ' ', '太', '好吃', '了', ' ', '今天', '早上', '到', '台南', '好市', '多', '買', '了', '兩台', '惠爾浦', '的', '除', '濕機', '因為', '在', '社團', '看到', '它', '的', '評價', '很', '好', '但是', '缺點', '就是', '噪音', '大', '但是', '沒有', '要', '放', '臥室', '…', '…', ' ', '顯示', '更', '多', '今天', '煮', '燉', '飯', '時', '，', '突發', '奇想', '地', '丟幾塊', 'kiri', '增加', '奶香', '&', '濃', '稠度', '，', '沒', '想到', '效果', '驚為', '天人', '！', '！', '！', '感覺', '拿', '來', '當白醬', '使用', '超級', '方便', '呀', '~', '~', '~', '推薦給', '大家', '試試', '！', '今天', '的', '主角', '不是', '我', '～', '是', '它們', '個', '人覺', '得', '元', '進莊', '的', '蔥', '油雞', '比', '全聯', '美味', '堂', '的', '好吃', '耶', '，', '口味', '比較', '重', '也', '更', '下', '飯', '，', '但', '兩家', '裏', '面附', '的', '蔥', '油', '包是', '一樣', '的', '。', '前次', '西瓜', '爆炸', '退款', '後', '，', '再', '賭瓜', '一次', '，', '這次', '西瓜', '好像', '貴', '了', '一點', '，', '大', '了', '一點', '，', '仔細', '挑選', '後', '沒', '爆炸', '的', '問題', '前陣子', '好市', '多', '的', ' ', '#', '雞肉凱', '撒', '沙拉', ' ', '漲價', '了', '，', '#', '昨天', '看到', '特價', '145', '元', '，', '覺得', '可以', '買來', '回味', '一下', '，', '不然', '那價格', '真的', '是', '越來', '越', '讓', '人', '不想', '下手', '…', '…', ' ', '顯示', '更', '多', '前陣子', '看', '社團', '被', '推坑', '買', '了', '英國潔', '，', '想要', '用來', '除黴', '，', '效果', '如', '照片', '所示', '，', '好不好', '用見', '仁見', '智', '（', '只能', '怪', '自己', '，', '後', '來', '才', '發現', '產品', '上', '說', '明鋁金', '屬面', '不', '適用', '）', '哇哇', '哇', '～', '～', '～', '太可愛了', '啦', '！', '超大', ' ', '#', '萌兔', '/', '#', '恐龍部隊', ' ', '出', '沒', '完全', '可以', '擄獲', '小女孩', '/', '小男孩', '的', '心', '啊', '～', '唉', ' ', '原本', '以為', '超幸運', '的', '在', '大順店', '剛好', '看到', '冰櫃裡', '剩下', '最', '後', '一盒', '立馬', '上前', '拿', '想', '說', '帶', '回家', '孝敬', '爸媽', '隔天', '迫不及待', '拿出', '來', '準備' ...
# {'#': 17, '歐美風': 1, '起司': 3, '拼盤': 1, '芝司': 1, '樂起': 1, '司球': 1, '高鈣': 1, 'Hoodys': 1, '精': 1, '緻': 1, '果': 1, '乾': 1, '富統': 1, '切片': 1, '火腿': 1, '…': 33, ' ': 56, '顯示': 15, '更': 16, '多': 31, '2022': 1, '/': 12, '05': 2, '29': 1, '蜂膠潤': 1, '喉糖': 1, '這個': 4, '好': 16, 'ㄔ': 1, '20220528': 1, '18': 1, ':': 4, '00': 1, '野馬樂': 1, '高': 3, '在': 10, '台': 2, '中店': 1, '(': 2, '南屯': 1, ')': 1, '還有': 3, '20': 1, '多盒': 1, '直接': 1, '搬': 2, '了': 23, '一盒': 2, '5': 1, '28': 1, '剛剛': 1, '11': 1, '50': 1, '中': 2, '好市': 14, 'B1': 1, '停車場': 1, '推車': 2, '上': 13, '發現': 4, '四瓶': 1, '牛奶': 2, '沒有': 4, '拿': 5, '，': 77, '趕時間': 1, '但': 2, '有': 14, '幫': 1, '這位': 1, '遺失者': 1, '通知': 1, '賣場': 2, '人員取': 1, '走': 3, '放至櫃': 1, '檯': 1, '。': 8, '（': 7, '照片': 2, '非': 1, '）': 7, 'IPad': 1, 'Air': 2, '大': 5, '缺貨': 1, '先來': 1, '一台': 3, 'MacBook': 1, '遠距': 1, '教學': 1, '最': 2, '後': 12, '金色': 1, '中和店': 1, '其它': 1, '顏色': 1, '蠻': 2, '多台': 1, '的': 60, '喔': 4, 'Lego': 1, '樂高': 1, '經典': 1, '系列': 1, '特價': 6, '$': 3, '999': 1, '[': 1, '地方': 1, '奶爸': 2, '日記': 1, ']': 1, '孩子': 1, '繼續線': 1, '課': 2, '一週': 1, '就': 5, '用': 9, '豬肉漢堡': 2, '排來': 1, '當一週': 1, '早餐': 3, '做好': 1, '以後放': 1, '冷凍': 2, '早上': 3, '放氣': 1, '炸鍋': 1, '氣炸': 1, '快速': 1, '上桌': 1, '小孩': 2, '可以': 7, '吃': 8, '美味': 2, '又': 3, '健康': 2, '！': 25, '兼職': 1, '攝影師': 1, '全職': 1, '排': 2, '不會': 4, '狠辣': 1, '丫舍': 1, '客家': 1, '麻辣': 1, '板條': 1, '全家': 1, '都': 16, '喜歡': 1, '加上': 1, '當季': 1, '食材': 1, '小黃瓜': 1, '很': 6, '爽口': 1, '￼': 1, '中午': 1, '經過': 4, '想': 4, '說': 6, '進去': 1, '買個': 1, '黃': 1, '色': 1, '萬': 1, '用布': 1, '巾': 1, '咖啡': 9, '機': 4, '展示': 1, '位': 1, '因為': 4, '沒': 6, '喝': 5, '很大': 1, '對': 3, '也': 10, '外行': 2, '考慮': 3, '一下': 4, '還是': 3, '買': 13, '人生': 1, '第一台': 1, '..': 2, '試玩': 1, '幾杯': 1, '設定': 1, '高水': 1, '溫覺': 1, '得': 3, '水溫': 1, '及': 1, '奶泡': 1, '溫度': 1, '還不夠': 1, '感覺': 3, '味道': 2, '不夠': 1, '衝腦': 1, '看來': 1, '還得': 1, '要': 8, '摸索': 1, '玩玩': 1, '看': 5, '最後有': 1, '個疑': 1, '問要': 1, '等': 1, '廠': 1, '商來': 1, '看看': 1, '怎麼': 3, '回事': 1, '就是': 2, '使用': 4, '廢': 1, '豆渣': 2, '盒': 1, '內會積': 1, '不少': 2, '水': 3, '水盤': 2, '會積': 1, '看起': 1, '來': 11, '設計': 1, '應該': 3, '是': 14, '這種': 1, '現像': 1, '才': 4, '...': 2, '續': 1, '一天': 1, '試作': 1, '水噴濺': 1, '狀況': 1, '已': 1, '明顯': 2, '改善': 1, '比較': 3, '和稀泥': 1, '製': 2, '作': 1, '過程': 1, '必須': 1, '清洗': 1, '動作': 1, '所': 1, '留下': 1, '正常': 3, '無異': 1, '目前': 1, '為止': 1, '算是': 1, '滿意': 1, '作出': 1, '我': 10, '預想': 1, '口感': 4, '要求': 1, '不': 7, '懂': 1, '眉眉角角': 1, '今天': 9, '天氣終': 1, '於': 2, '放晴': 1, '炎炎夏日': 1, '立馬': 2, '把': 4, 'Costco': 1, 'Arla': 1, '鮮': 2, '奶油': 2, '拿出': 2, '做': 2, '芒果': 1, '冰淇淋': 1, '我的媽': 1, '啊': 5, '太': 3, '好吃': 6, '到': 5, '台南': 1, '兩台': 1, '惠爾浦': 1, '除': 2, '濕機': 1, '社團': 3, '看到': 7, '它': 2, '評價': 1, '但是': 2, '缺點': 1, '噪音': 1, '放': 1, '臥室': 1, '煮': 4, '燉': 1, '飯': 2, '時': 2, '突發': 1, '奇想': 1, '地': 1, '丟幾塊': 1, 'kiri': 1, '增加': 1, '奶香': 1, '&': 1, '濃': 1, '稠度': 1, '想到': 3, '效果': 2, '驚為': 1, '天人': 1, '當白醬': 1, '超級': 3, '方便': 1, '呀': 1, '~': 7, '推薦給': 1, '大家': 5, '試試': 1, '主角': 1, '不是': 1, '～': 8, '它們': 1, '個': 2, '人覺': 1, '元': 3, '進莊': 1, '蔥': 2, '油雞': 1, '比': 5, '全聯': 1, '堂': 1, '耶': 4, '口味': 1, '重': 1, '下': 1, '兩家': 1, '裏': 1, '面附': 1, '油': 2, '包是': 1, '一樣': 1, '前次': 1, '西瓜': 2, '爆炸': 2, '退款': 1, '再': 1, '賭瓜': 1, '一次': 2, '這次': 1, '好像': 2, '貴': 1, '一點': 4, '仔細': 1, '挑選': 1, '問題': 2, '前陣子': 2, '雞肉凱': 1, '撒': 1, '沙拉': 1, '漲價': 2, '昨天': 1, '145': 1, '覺得': 3, '買來': 1, '回味': 1, '不然': 3, '那價格': 1, '真的': 6, '越來': 1, '越': 1, '讓': 1, '人': 4, '不想': 2, '下手': 1, '被': 2, '推坑': 1, '英國潔': 1, '想要': 2, '用來': 1, '除黴': 1, '如': 1, '所示': 1, '好不好': 1, '用見': 1, '仁見': 1, '智': 1, '只能': 1, '怪': 1, '自己': 2, '產品': 1, '明鋁金': 1, '屬面': 1, '適用': 1, '哇哇': 1, '哇': 1, '太可愛了': 1, '啦': 1, '超大': 1, '萌兔': 1, '恐龍部隊': 1, '出': 1, '完全': 1, '擄獲': 1, '小女孩': 1, '小男孩': 1, '心': 1, '唉': 1, '原本': 1, '以為': 1, '超幸運': 1, '大順店': 1, '剛好': 3, '冰櫃裡': 1, '剩下': 1, '上前': 1, '帶': 1, '回家': 1, '孝敬': 1, '爸媽': 1, '隔天': 1, '迫不及待': 1, '準備': 1, '享用': 1, '一打': 2, '開': 3, '黑黑的': 1, '蘇菲衛生': 1, '棉': 2, '很多': 1, '款': 1, '然': 1, '這盒': 1, '拉': 2, '麵': 3, '希望': 1, '出來': ...
#      num  word
# 0     17  請問
# 1     15  顯示
# 2     14  好市
# 3      9  咖啡
# 4      9  今天
# ..   ...   ...
# 127    2  大大
# 128    2  這罐
# 129    2  殘膠
# 130    2  防疫
# 131    2  媽媽
#
# [132 rows x 2 columns]
# 48 筆舊資料已删除
#                                                               商品名稱  \
# 0                        Koh Coconut 椰奶 1公升 X 6入
# 1   Kirkland Signature 科克蘭 無調味綜合堅果 1.13公斤
# 2                     Tartuferia 黑松露菌菇醬 500公克
# 3                   王品 冷凍青花驕經典麻辣鍋 1.6公斤
# 4                   口福不淺 有機雙麻派 25公克 X 20入
# 5                             老食粹 有機枸杞 600公克
# 6                             老食粹 有機紅棗 600公克
# 7   Kirkland Signature 科克蘭 有機益生菌綜合早餐穀片1公斤......
# 8   Kirkland Signature 科克蘭有機蘇門答臘咖啡豆 907公克......
# 9   Kirkland Signature 科克蘭 有機檸檬果汁飲料 2.84公升 X 2入......
# 10                          冷凍檸檬風味奶油蝦串 9 入
# 11  Kirkland Signature 科克蘭有機巧克力保久調味乳 244毫升 X 24入.....
# 12               Dum Dums 綜合口味立袋棒棒糖 1.44公斤
# 13                      喜年來 原味蛋捲 72公克 X 20入
# 14                     愛之味 純濃燕麥 340毫升 X 12入
# 15      Kirkland Signature 科克蘭 泉水 600毫升 X 30瓶
# 16                        Nu-Pure 泉水 250毫升 X 40瓶
# 17                   Evian 天然礦泉水 1500毫升 X 12入
# 18                   卡樂比 富果樂水果早餐麥片 1 公斤
# 19              家樂氏 Special K 草莓早餐脆片 1.2公斤
# 20                           Koh 純椰子汁 1公升 X 6入
# 21                              北海 鱈魚香絲 600公克
# 22                                 Kewpie 胡麻醬1公升
# 23                     ARM & HAMMER 小蘇打粉 6.12公斤
# 24  Kirkland Signature 科克蘭 冷凍去殼去尾養殖大生蝦仁 908公克 - 50...
# 25                            健司 纖三薯脆片 400公克
# 26                          Chosen Foods 酪梨油 1公升
# 27  Kirkland Signature 科克蘭 韓國鹽烤海苔 17公克 X 10入......
# 28                 樂天 優格風味碳酸飲 250毫升 X 30入
# 29             西雅圖 無加糖二合一咖啡 21公克 X 100入
# 30                       桂格減糖黑十穀 38公克 X 50入
# 31        Kirkland Signature 科克蘭 冷凍藍莓 2.27公斤
# 32              Ocean Spray 蔓越莓乾減糖配方 1221公克
# 33                Barilla 百味來 義大利天使麵 500公克
# 34           Perrier 沛綠雅 氣泡礦泉水 500毫升 X 24瓶
# 35                  康寶 金黃玉米濃湯 56.3公克 X 10包
# 36  Kirkland Signature 科克蘭 冷凍帶尾特大養殖生蝦仁 908公克 - 31-...
# 37                         桂格黃金麩片燕麥片 1.7公斤
# 38              日本特選和風鰹魚高湯包 8.8公克 X 20包
# 39    Kirkland Signature 科克蘭 氣泡水 500毫升 X 40瓶
# 40                  Magnum 熱帶雨林有機咖啡豆 907公克
# 41                       Jose's 香草味咖啡豆 1.36公斤
# 42                     韓味不二 鹽烤海苔 5公克 X 36入
# 43                           新東陽精緻豬肉鬆 270公克
# 44                              曾拌麵 116公克 X 12包
# 45                             冷凍七星鱸魚排 1.2公斤
# 46                         Daisho 日式燒肉醬 1.15公斤
# 47      Kirkland Signature 科克蘭 冷凍鮭魚排 1.36公斤
#
#    商品價格                                               網址
# 0      $379  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 1      $599  https://www.costco.com.tw/Food/Snacks/Nuts-Chi...
# 2      $489  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 3      $499  https://www.costco.com.tw/Wowprime/Wowprime-Fr...
# 4      $369  https://www.costco.com.tw/Food/Snacks/Cookies-...
# 5      $489  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 6      $319  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 7      $299  https://www.costco.com.tw/Food/Drinks/Powdered...
# 8      $469  https://www.costco.com.tw/Water-Beverages/Kirk...
# 9      $309  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 10     $499  https://www.costco.com.tw/Food/Frozen-Foods/Me...
# 11     $649  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 12     $389  https://www.costco.com.tw/Food/Snacks/Chocolat...
# 13     $449  https://www.costco.com.tw/Food/Snacks/Cookies-...
# 14     $299  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 15     $319  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 16     $269  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 17     $659  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 18     $349  https://www.costco.com.tw/Food/Drinks/Powdered...
# 19     $389  https://www.costco.com.tw/Food/Drinks/Powdered...
# 20     $459  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 21     $289  https://www.costco.com.tw/Food/Snacks/Nuts-Chi...
# 22     $239  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 23     $299  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 24     $589  https://www.costco.com.tw/Food/Frozen-Foods/Me...
# 25     $295  https://www.costco.com.tw/Food/Snacks/Nuts-Chi...
# 26     $399  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 27     $389  https://www.costco.com.tw/Food/Snacks/Cookies-...
# 28     $459  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 29     $649  https://www.costco.com.tw/Food/Drinks/Coffee-T...
# 30     $329  https://www.costco.com.tw/Food/Drinks/Powdered...
# 31     $539  https://www.costco.com.tw/Food/Frozen-Foods/Fr...
# 32     $359  https://www.costco.com.tw/Food/Snacks/Cookies-...
# 33      $79  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 34     $739  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 35     $299  https://www.costco.com.tw/Food/Prepared-Canned...
# 36     $589  https://www.costco.com.tw/Food/Frozen-Foods/Me...
# 37     $249  https://www.costco.com.tw/Food/Drinks/Powdered...
# 38     $319  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 39     $399  https://www.costco.com.tw/Food/Drinks/Water-Be...
# 40     $369  https://www.costco.com.tw/Food/Drinks/Coffee-T...
# 41     $549  https://www.costco.com.tw/Food/Drinks/Coffee-T...
# 42     $449  https://www.costco.com.tw/Food/Snacks/Cookies-...
# 43     $165  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 44     $429  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 45     $649  https://www.costco.com.tw/Food/Frozen-Foods/Me...
# 46     $185  https://www.costco.com.tw/Food/Pantry-Dry-Good...
# 47   $1,219  https://www.costco.com.tw/Food/Frozen-Foods/Me...
# 48 筆舊資料已删除
# C:\Users\user\AppData\Local\Temp/ipykernel_11876/89996482.py:296: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path = 'C:\\Users\\user\\chromedriver.exe',options=chrome_options)
#                                              商品名稱  \
# 0                      Mackie's 經典牛奶冰淇淋 2 公升
# 1               明治 北海道牛奶香草雪糕 43毫升 X 30枝
# 2                      Kirkland Signature 科克蘭 小管
# 3                                北海道生干貝 S 1公斤
# 4                 養樂多 300活菌發酵乳 100毫升 X 40入
# 5   Kirkland Signature 科克蘭 全脂鮮乳 1.89公升 X 2瓶
# 6                       雀巢 咖啡伴侶原味罐裝 1.5公斤
# 7                                 泰山大豆沙拉油5公升
# 8                                 LH中筋麵粉1公斤X3包
# 9                                 LH高筋麵粉1公斤X3包
# 10                             TWS精製砂糖(二砂)2公斤
# 11                                   TWS特級砂糖2公斤
# 12                                   TWS結晶冰糖2公斤
# 13                                TWS手工純黑糖2 公斤
# 14                         非凡比整支玉米筍 2.95 公斤
# 15                                           切塊蕃茄
# 16                                             蕃茄泥
# 17                                             蕃茄糊
# 18                                             蕃茄醬
# 19                   PRIMA TASTE 新加坡叻沙225公克X 3
# 20                                         漢堡包15入
# 21         Kirkland Signature 科克蘭綜合貝果麵包 12入
# 22        Kirkland Signature 科克蘭 法國迷你可鬆 28入
# 23                                       法國可鬆12入
# 24                  斐濟天然深層礦泉水 500毫升 X 24瓶
# 25                    EVIAN法國天然礦泉水500毫升X30入
# 26                          義美蜂蜜蛋糕400公克X2條入
# 27                            雪碧易開罐330毫升X 32入
# 28                           原萃日式綠茶575毫升/24入
# 29                Cavendish Farms 薯餅 20入 / 1.2公斤
# 30                                 石安牧場溫泉蛋16入
# 31                        石安牧場香滷蛋白丁 100GX6入
# 32                               義美厚奶茶 946MLX3入
# 33                         傳貴有機無糖豆漿 900MLX3入
# 34                      福樂頂級多莓果優酪乳 1.7LX2入
# 35              福樂 頂級無加糖優酪乳 1.7公升 X 2瓶入
# 36                        ZANETTI 瑪斯卡邦乳酪500公克
# 37                               吉利乾酪點心18GX24入
# 38                   BelGioioso 摩佐羅拉乾酪切片 907g
# 39                        Arla 哈伐第切片乾酪 907公克
# 40                                     精選乾酪綜合包
# 41            芝司樂 香濃原味高鈣起司球 150公克 X 2入
# 42                    笑牛 原味迷你乾酪 250公克 X 2入
# 43                        台畜萬巒豬腳1.2公斤(附沾醬)
# 44                                  台畜梅干扣肉1公斤
# 45                     TIBALDI燻烤去骨火腿片250公克*2
# 46                              富統迷迭香雞腿排1公斤
# 47                          紅龍椒麻雞丁600公克 X 2入
#
#                                                  網址
# 0   https://www.costco.com.tw//Warehouse-Only/Food...
# 1   https://www.costco.com.tw//Warehouse-Only/Food...
# 2   https://www.costco.com.tw//Warehouse-Only/Food...
# 3   https://www.costco.com.tw//Warehouse-Only/Food...
# 4   https://www.costco.com.tw//Warehouse-Only/Food...
# 5   https://www.costco.com.tw//Warehouse-Only/Food...
# 6   https://www.costco.com.tw//Warehouse-Only/Food...
# 7   https://www.costco.com.tw//Warehouse-Only/Food...
# 8   https://www.costco.com.tw//Warehouse-Only/Food...
# 9   https://www.costco.com.tw//Warehouse-Only/Food...
# 10  https://www.costco.com.tw//Warehouse-Only/Food...
# 11  https://www.costco.com.tw//Warehouse-Only/Food...
# 12  https://www.costco.com.tw//Warehouse-Only/Food...
# 13  https://www.costco.com.tw//Warehouse-Only/Food...
# 14  https://www.costco.com.tw//Warehouse-Only/Food...
# 15  https://www.costco.com.tw//Warehouse-Only/Food...
# 16  https://www.costco.com.tw//Warehouse-Only/Food...
# 17  https://www.costco.com.tw//Warehouse-Only/Food...
# 18  https://www.costco.com.tw//Warehouse-Only/Food...
# 19  https://www.costco.com.tw//Warehouse-Only/Food...
# 20  https://www.costco.com.tw//Warehouse-Only/Food...
# 21  https://www.costco.com.tw//Warehouse-Only/Food...
# 22  https://www.costco.com.tw//Warehouse-Only/Food...
# 23  https://www.costco.com.tw//Warehouse-Only/Food...
# 24  https://www.costco.com.tw//Warehouse-Only/Food...
# 25  https://www.costco.com.tw//Warehouse-Only/Food...
# 26  https://www.costco.com.tw//Warehouse-Only/Food...
# 27  https://www.costco.com.tw//Warehouse-Only/Food...
# 28  https://www.costco.com.tw//Warehouse-Only/Food...
# 29  https://www.costco.com.tw//Warehouse-Only/Food...
# 30  https://www.costco.com.tw//Warehouse-Only/Food...
# 31  https://www.costco.com.tw//Warehouse-Only/Food...
# 32  https://www.costco.com.tw//Warehouse-Only/Food...
# 33  https://www.costco.com.tw//Warehouse-Only/Food...
# 34  https://www.costco.com.tw//Warehouse-Only/Food...
# 35  https://www.costco.com.tw//Warehouse-Only/Food...
# 36  https://www.costco.com.tw//Warehouse-Only/Food...
# 37  https://www.costco.com.tw//Warehouse-Only/Food...
# 38  https://www.costco.com.tw//Warehouse-Only/Food...
# 39  https://www.costco.com.tw//Warehouse-Only/Food...
# 40  https://www.costco.com.tw//Warehouse-Only/Food...
# 41  https://www.costco.com.tw//Warehouse-Only/Food...
# 42  https://www.costco.com.tw//Warehouse-Only/Food...
# 43  https://www.costco.com.tw//Warehouse-Only/Food...
# 44  https://www.costco.com.tw//Warehouse-Only/Food...
# 45  https://www.costco.com.tw//Warehouse-Only/Food...
# 46  https://www.costco.com.tw//Warehouse-Only/Food...
# 47  https://www.costco.com.tw//Warehouse-Only/Food...
# C:\Users\user\anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '..']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '...']
# None
#      num  word                                                   商品名稱  \
# 0     17  請問                                                NaN
# 1     15  顯示                                                NaN
# 2     14  好市                                                NaN
# 3      9  咖啡  Kirkland Signature 科克蘭有機蘇門答臘咖啡豆 907公克......
# 4      9  今天                                                NaN
# ..   ...   ...                                                ...
# 127    2  大大                                                NaN
# 128    2  這罐                                                NaN
# 129    2  殘膠                                                NaN
# 130    2  防疫                                                NaN
# 131    2  媽媽                                                NaN
#
#     商品價格                                               網址
# 0        NaN                                                NaN
# 1        NaN                                                NaN
# 2        NaN                                                NaN
# 3       $469  https://www.costco.com.tw/Water-Beverages/Kirk...
# 4        NaN                                                NaN
# ..       ...                                                ...
# 127      NaN                                                NaN
# 128      NaN                                                NaN
# 129      NaN                                                NaN
# 130      NaN                                                NaN
# 131      NaN                                                NaN
#
# [132 rows x 5 columns]
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\user\AppData\Local\Temp/ipykernel_11876/89996482.py", line 411, in shoplist1
#     a=final_dict["商品名稱"][num],final_dict["商品價格"][num],final_dict["網址"][num]
# IndexError: list index out of range
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '..']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '...']
#      num  word                       商品名稱  \
# 0     17  請問                            NaN
# 1     15  顯示                            NaN
# 2     14  好市                            NaN
# 3      9  咖啡  雀巢 咖啡伴侶原味罐裝 1.5公斤
# 4      9  今天                            NaN
# ..   ...   ...                            ...
# 127    2  大大            泰山大豆沙拉油5公升
# 128    2  這罐        雪碧易開罐330毫升X 32入
# 129    2  殘膠                            NaN
# 130    2  防疫                            NaN
# 131    2  媽媽                            NaN
#
#                                                   網址
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    https://www.costco.com.tw//Warehouse-Only/Food...
# 4                                                  NaN
# ..                                                 ...
# 127  https://www.costco.com.tw//Warehouse-Only/Food...
# 128  https://www.costco.com.tw//Warehouse-Only/Food...
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
#
# [132 rows x 4 columns]
#                         商品名稱  \
# 1  雀巢 咖啡伴侶原味罐裝 1.5公斤
# 2                   法國可鬆12入
# 3               TWS特級砂糖2公斤
#
#                                                 網址
# 1  https://www.costco.com.tw//Warehouse-Only/Food...
# 2  https://www.costco.com.tw//Warehouse-Only/Food...
# 3  https://www.costco.com.tw//Warehouse-Only/Food...
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\user\AppData\Local\Temp/ipykernel_11876/89996482.py", line 477, in shoplist2
#     b=final_dict2["商品名稱"][num],final_dict2["網址"][num]
# IndexError: list index out of range
# link: https://www.costco.com.tw/Water-Beverages/Kirkland-Signature-Organic-Sumatra-Coffee-Bean-907-g/p/1163683
# link: https://www.costco.com.tw/Food/Pantry-Dry-Goods/Dried-Grocery-Grains/Lao-Shi-Cui-Organic-Goji-600-g/p/126818
# link: https://www.costco.com.tw//Warehouse-Only/Food-Beverages/Water-Beverages/NESTLE-COFFEE-MATE-56OZ-15KG/p/541334
# link: https://www.costco.com.tw/Water-Beverages/Kirkland-Signature-Organic-Sumatra-Coffee-Bean-907-g/p/1163683
# link: https://www.costco.com.tw//Warehouse-Only/Food-Beverages/Dry-Grocery/FRENCH-CROISSANT-12CT/p/111891
# link: https://www.costco.com.tw/Water-Beverages/Kirkland-Signature-Organic-Sumatra-Coffee-Bean-907-g/p/1163683
# link: https://www.costco.com.tw//Warehouse-Only/Food-Beverages/Dry-Grocery/FRENCH-CROISSANT-12CT/p/111891
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11876/89996482.py in <module>
#     565
#     566 window.resizable(False, False)
# --> 567 window.mainloop()
#
# ~\anaconda3\lib\tkinter\__init__.py in mainloop(self, n)
#    1427     def mainloop(self, n=0):
#    1428         """Call the mainloop of Tk."""
# -> 1429         self.tk.mainloop(n)
#    1430
#    1431     def quit(self):
#
# KeyboardInterrupt:
